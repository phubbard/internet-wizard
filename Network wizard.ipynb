# %%
from ping3 import ping
from diagnose import *
from dns import *

print(f'{ping("wifi")=}')
print(f'{ping("204.128.136.11")=}')
print(f'{ping("fratboy")=}')
print(f'{ping("modem")=}')
print(f'{ping("8.8.8.8")=}')
print(f'{ping("google.com")=}')
print(f'{ping("cloudflare.com")=}')

print(f"{lookup_domain('google.com')=}")
can_ping_all(REMOTE_IPS)
# Out:
# ping("wifi")=0.0028901100158691406
# ping("204.128.136.11")=0.0027701854705810547
# ping("fratboy")=0.002847909927368164
# ping("modem")=0.006129741668701172
# ping("8.8.8.8")=0.019171714782714844
# ping("google.com")=0.01792001724243164
# ping("cloudflare.com")=0.016993045806884766
# lookup_domain('google.com')='142.250.189.14'
# Pinging 8.8.8.8...
# up
# Pinging 9.9.9.9...
# up
# Pinging 1.1.1.1...
# up
# True

# %%
local_network_up()
# Out:
# Pinging 192.168.100.1...
# up
# Pinging 204.128.136.11...
# up
# Pinging 204.128.136.5...
# up
# Pinging 204.128.136.2...
# up
# Resolving usul with 204.128.136.5...
# ok ip='204.128.136.1'
# Resolving modem with 204.128.136.5...
# fail
# Resolving wifi with 204.128.136.5...
# ok ip='204.128.136.15'
# Resolving fratboy with 204.128.136.5...
# fail
# Pinging fratboy...
# up
# Pinging modem...
# up
# Pinging wifi...
# up
# Pinging 8.8.8.8...
# up
# Pinging 9.9.9.9...
# up
# Pinging 1.1.1.1...
# up
# Looking up google.com with 8.8.8.8...
# ok
# Looking up cloudflare.com with 8.8.8.8...
# ok
# Resolving www.google.com with 8.8.8.8...
# ok ip='142.250.72.132'
# Resolving www.cloudflare.com with 8.8.8.8...
# ok ip='104.16.123.96'
# local_network='ok' local_dns='fail' router='ok' modem='ok' wifi='ok' remote_network='ok' remote_domains='ok'
# remote_hosts='ok'
# '[green]ok[/]'

# %%
lookup_host('modem', nameserver='204.128.136.5')
